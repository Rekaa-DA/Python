# %% [markdown]
# <a href="https://colab.research.google.com/github/Rekaa-DA/Python/blob/main/String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name_full = input("enter full_name :").lower().replace(" ", ".").split(".")
Name = " ".join(name_full)
Domain = input("enter domain_name :")
email = f"{Name.replace(' ', '')}@{Domain}" # Concatenate strings using an f-string
print(f"My name is :{Name}")
print(f"My Email id is :{email}")
# Out:
# enter full_name :REKAA SELVARAJ
# enter domain_name :GMAIL
# My name is :rekaa selvaraj
# My Email id is :rekaaselvaraj@GMAIL

# %%
from typing import Concatenate
name = input("enter full_name :").lower().replace(" ", ".")
domain = input("enter domain name :")
email = name+"@"+domain
print(f"My name is :{Name}")
print(f"My Email id is :{email}")
# Out:
# enter full_name :Ravi Kumar
# enter domain namegmail.com
# My name is :rekaa selvaraj
# My Email id is :ravi.kumar@gmail.com

# %%
a = int(3)
b = int(4)
c = a + b

print(int(c))
# Out:
# 7

# %%
a = float(30.80)
b = float(20.50)
c = a - b
print(float(c))
print(type(c))
# Out:
# 10.3
# <class 'float'>

# %%
a =  int(15)
b = int(10)
c = a * b
print(int(c))
# Out:
# 150

# %%
a = int(25)
b = int(5)
c = a / b
print(int(c))
# Out:
# 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
Word = input("Enter word :")
print(Word)
Length = len(Word)
print(Length)
count = Word.count("e")
print(count)
count_Word = Word.count("like")
print(count_Word)
# Out:
# Enter word :i like to fly like a bird like
# i like to fly like a bird like
# 30
# 3
# 3

# %%
print(Word[::-1])
# Out:
# ekil drib a ekil ylf ot ekil i

# %%
Text = input("Enter text : ")

if Text in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter text : janskjjSBJk
# Consonant

# %%
palindrome = input("Enter text : ")

if palindrome == palindrome[::-1]:
 print("Palindrome")
# Out:
# Enter text : madam
# Palindrome

# %%
a = [2]
print(id(a))

a.append(10)
print(id(a))
# Out:
# 135931149243520
# 135931149243520

# %%
b = 2

print(id(b))

b = b + 10

print(id(b))
# Out:
# 11645384
# 11645704

# %%
student = ("ravi", 25 , "Sql")
name , age , course = student
print(name)
# Out:
# ravi

# %%
print(age)
print(course)
# Out:
# 25
# Sql

# %%
student = (name,age,course)
print(student)
print(type(student))
# Out:
# ('ravi', 25, 'Sql')
# <class 'tuple'>

# %%
Order = (1,"Boost",2,250,"Done")

order_id, product_name, quantity, price, status = Order

print(order_id)
print(product_name)
print(quantity)
print(price)
print(status)
# Out:
# 1
# Boost
# 2
# 250
# Done

# %%
price = 250 + 50

# %%
Order = (order_id, product_name, quantity, price, status)
print(Order)
print(type(Order))
# Out:
# (1, 'Boost', 2, 300, 'Done')
# <class 'tuple'>
